# %%
import pandas as pd

df_african_cup_matches = pd.read_csv('Africa Cup of Nations Matches.csv')
display(df_african_cup_matches.head(3))
# Out:
#    Year      Date  Time    HomeTeam       AwayTeam  HomeTeamGoals  \
# 0  1957  10-Feb-57   NaN     Sudan           Egypt            1.0
# 1  1957  10-Feb-57   NaN  Ethiopia    South Africa            NaN
# 2  1957  16-Feb-57   NaN     Egypt        Ethiopia            4.0
#
#    AwayTeamGoals       Stage  \
# 0            2.0  Semifinals
# 1            NaN  Semifinals
# 2            0.0       Final
#
#                                 SpecialWinConditions            Stadium  \
# 0                                                NaN  Municipal Stadium
# 1  Ethiopia  wins due to disqualification of othe...                NaN
# 2                                                NaN  Municipal Stadium
#
#         City  Attendance
# 0   Khartoum     30000.0
# 1        NaN         NaN
# 2   Khartoum     30000.0

# %% [markdown]
# # Working with missing data with pandas

# %% [markdown]
# ## 1. DataFrame.isna()

# %%
df_african_cup_matches.isna()
# Out:
#       Year  Date   Time   HomeTeam  AwayTeam  HomeTeamGoals  AwayTeamGoals  \
# 0    False  False   True     False     False          False          False
# 1    False  False   True     False     False           True           True
# 2    False  False   True     False     False          False          False
# 3    False  False   True     False     False          False          False
# 4    False  False   True     False     False          False          False
# ..     ...    ...    ...       ...       ...            ...            ...
# 617  False  False  False     False     False          False          False
# 618  False  False  False     False     False          False          False
# 619  False  False  False     False     False          False          False
# 620  False  False  False     False     False          False          False
# 621  False  False  False     False     False          False          False
#
#      Stage  SpecialWinConditions  Stadium   City  Attendance
# 0    False                  True    False  False       False
# 1    False                 False     True   True        True
# 2    False                  True    False  False       False
# 3    False                  True    False  False       False
# 4    False                  True    False  False       False
# ..     ...                   ...      ...    ...         ...
# 617  False                  True    False  False       False
# 618  False                 False    False  False       False
# 619  False                  True    False  False       False
# 620  False                  True    False  False       False
# 621  False                  True    False  False       False
#
# [622 rows x 12 columns]

# %% [markdown]
# ## 2.df.notna()

# %%
df_african_cup_matches.notna()
# Out:
#      Year  Date   Time   HomeTeam  AwayTeam  HomeTeamGoals  AwayTeamGoals  \
# 0    True   True  False      True      True           True           True
# 1    True   True  False      True      True          False          False
# 2    True   True  False      True      True           True           True
# 3    True   True  False      True      True           True           True
# 4    True   True  False      True      True           True           True
# ..    ...    ...    ...       ...       ...            ...            ...
# 617  True   True   True      True      True           True           True
# 618  True   True   True      True      True           True           True
# 619  True   True   True      True      True           True           True
# 620  True   True   True      True      True           True           True
# 621  True   True   True      True      True           True           True
#
#      Stage  SpecialWinConditions  Stadium   City  Attendance
# 0     True                 False     True   True        True
# 1     True                  True    False  False       False
# 2     True                 False     True   True        True
# 3     True                 False     True   True        True
# 4     True                 False     True   True        True
# ..     ...                   ...      ...    ...         ...
# 617   True                 False     True   True        True
# 618   True                  True     True   True        True
# 619   True                 False     True   True        True
# 620   True                 False     True   True        True
# 621   True                 False     True   True        True
#
# [622 rows x 12 columns]

# %% [markdown]
# ## 3. df.notna() and df.notnull()

# %%
df_african_cup_matches.notna()
df_african_cup_matches.notnull()
# Out:
#      Year  Date   Time   HomeTeam  AwayTeam  HomeTeamGoals  AwayTeamGoals  \
# 0    True   True  False      True      True           True           True
# 1    True   True  False      True      True          False          False
# 2    True   True  False      True      True           True           True
# 3    True   True  False      True      True           True           True
# 4    True   True  False      True      True           True           True
# ..    ...    ...    ...       ...       ...            ...            ...
# 617  True   True   True      True      True           True           True
# 618  True   True   True      True      True           True           True
# 619  True   True   True      True      True           True           True
# 620  True   True   True      True      True           True           True
# 621  True   True   True      True      True           True           True
#
#      Stage  SpecialWinConditions  Stadium   City  Attendance
# 0     True                 False     True   True        True
# 1     True                  True    False  False       False
# 2     True                 False     True   True        True
# 3     True                 False     True   True        True
# 4     True                 False     True   True        True
# ..     ...                   ...      ...    ...         ...
# 617   True                 False     True   True        True
# 618   True                  True     True   True        True
# 619   True                 False     True   True        True
# 620   True                 False     True   True        True
# 621   True                 False     True   True        True
#
# [622 rows x 12 columns]

# %% [markdown]
# ## 4. df.dropna()

# %%
df_african_cup_matches.dropna()
# Out:
#      Year                      Date           Time        HomeTeam  \
# 315  1998                  21-Feb-98          17:00       Tunisia
# 316  1998                  21-Feb-98          20:00   Ivory Coast
# 318  1998                  25-Feb-98          16:00      DR Congo
# 320  1998                  27-Feb-98          16:00      DR Congo
# 349  2000                   7-Feb-00          19:00       Nigeria
# 352  2000                  12-Feb-00          16:00  South Africa
# 353  2000                  13-Feb-00          16:00       Nigeria
# 382  2002                   7-Feb-02          16:00       Nigeria
# 385  2002                  10-Feb-02          16:00       Senegal
# 413  2004                   8-Feb-04          17:00       Morocco
# 414  2004                  11-Feb-04          16:00       Tunisia
# 444  2006                   4-Feb-06          15:00       Nigeria
# 445  2006                   4-Feb-06          19:00      Cameroon
# 449  2006                  10-Feb-06          18:00         Egypt
# 477  2008                   4-Feb-08          20:30       Tunisia
# 507  2010                  24-Jan-10          20:30   Ivory Coast
# 508  2010                  25-Jan-10          17:00         Egypt
# 509  2010                  25-Jan-10          20:30        Zambia
# 516  2012                   5-Feb-12          17:00         Gabon
# 517  2012                   5-Feb-12          20:00         Ghana
# 521  2012                  12-Feb-12  20:30[note 1]        Zambia
# 523  2013                   2-Feb-13          20:30  South Africa
# 525  2013                   3-Feb-13          20:30  Burkina Faso
# 527  2013                   6-Feb-13          20:30  Burkina Faso
# 531  2015                  31-Jan-15          20:30       Tunisia
# 537  2015                   8-Feb-15          20:00   Ivory Coast
# 606  2019   5 July 2019 (2019-07-05)          18:00       Morocco
# 610  2019   7 July 2019 (2019-07-07)          18:00    Madagascar
# 613  2019   8 July 2019 (2019-07-08)          21:00         Ghana
# 616  2019  11 July 2019 (2019-07-11)          18:00   Ivory Coast
# 618  2019  14 July 2019 (2019-07-14)          18:00       Senegal
#
#                AwayTeam  HomeTeamGoals  AwayTeamGoals              Stage  \
# 315        Burkina Faso            1.0            1.0      Quarterfinals
# 316               Egypt            0.0            0.0      Quarterfinals
# 318        South Africa            1.0            2.0         Semifinals
# 320        Burkina Faso            4.0            4.0  Third place match
# 349             Senegal            2.0            1.0      Quarterfinals
# 352             Tunisia            2.0            2.0  Third place match
# 353            Cameroon            2.0            2.0              Final
# 382             Senegal            1.0            2.0         Semifinals
# 385            Cameroon            0.0            0.0              Final
# 413             Algeria            3.0            1.0     Quarter-finals
# 414             Nigeria            1.0            1.0        Semi-finals
# 444             Tunisia            1.0            1.0     Quarter-finals
# 445         Ivory Coast            1.0            1.0     Quarter-finals
# 449         Ivory Coast            0.0            0.0              Final
# 477            Cameroon            2.0            3.0     Quarter-finals
# 507             Algeria            2.0            3.0     Quarter-finals
# 508            Cameroon            3.0            1.0     Quarter-finals
# 509             Nigeria            0.0            0.0     Quarter-finals
# 516                Mali            1.0            1.0      Quarterfinals
# 517             Tunisia            2.0            1.0      Quarterfinals
# 521         Ivory Coast            0.0            0.0              Final
# 523                Mali            1.0            1.0     Quarter-finals
# 525                Togo            1.0            0.0     Quarter-finals
# 527               Ghana            1.0            1.0        Semi-finals
# 531   Equatorial Guinea            1.0            2.0     Quarter-finals
# 537               Ghana            0.0            0.0              Final
# 606               Benin            1.0            1.0        Round of 16
# 610            DR Congo            2.0            2.0        Round of 16
# 613             Tunisia            1.0            1.0        Round of 16
# 616             Algeria            1.0            1.0     Quarter-finals
# 618             Tunisia            1.0            0.0        Semi-finals
#
#                      SpecialWinConditions                         Stadium  \
# 315    Burkina Faso win on Penalities 7-8                 Stade du 4-Août
# 316           Egypt win on Penalities 4-5                 Stade Municipal
# 318                 win after extra time                  Stade du 4-Août
# 320       DR Congo  win on Penalities 4-1                 Stade Municipal
# 349                 win after extra time                 National Stadium
# 352   South Africa  win on Penalities 4-3            Accra Sports Stadium
# 353        Cameroon win on Penalities 3-4                National Stadium
# 382                 win after extra time               Stade Modibo Keïta
# 385        Cameroon win on Penalities 2-3                Stade du 26 Mars
# 413                 win after extra time             Stade Taïeb El Mhiri
# 414        Tunisia  win on Penalities 5-3                Stade 7 Novembre
# 444        Nigeria  win on Penalities 6-5               Port Said Stadium
# 445   Ivory Coast win on Penalities 11-12  Cairo Military Academy Stadium
# 449          Egypt  win on Penalities 4-2     Cairo International Stadium
# 477                 win after extra time                   Tamale Stadium
# 507                 win after extra time                Estádio do Chiazi
# 508                 win after extra time       Estádio Nacional de Ombaka
# 509         Nigeria win on Penalities 4-5   Estádio Nacional da Tundavala
# 516            Mali win on Penalities 4-5                Stade d'Angondjé
# 517                 win after extra time             Stade de Franceville
# 521         Zambia  win on Penalities 8-7                Stade d'Angondjé
# 523            Mali win on Penalities 1-3           Moses Mabhida Stadium
# 525                 win after extra time                 Mbombela Stadium
# 527   Burkina Faso  win on Penalities 3-2                Mbombela Stadium
# 531                 win after extra time                  Estadio de Bata
# 537    Ivory Coast  win on Penalities 9-8                 Estadio de Bata
# 606           Benin win on Penalities 1-4                Al Salam Stadium
# 610     Madagascar  win on Penalities 4-2              Alexandria Stadium
# 613         Tunisia win on Penalities 4-5                Ismailia Stadium
# 616         Algeria win on Penalities 3-4                    Suez Stadium
# 618                 win after extra time                  30 June Stadium
#
#              City  Attendance
# 315   Ouagadougou     35000.0
# 316   Ouagadougou     20000.0
# 318   Ouagadougou      4000.0
# 320   Ouagadougou     25000.0
# 349         Lagos     60000.0
# 352         Accra      1000.0
# 353         Lagos     60000.0
# 382        Bamako     20000.0
# 385        Bamako     50000.0
# 413          Sfax     22000.0
# 414         Radès     56000.0
# 444     Port Said     10000.0
# 445         Cairo      4000.0
# 449         Cairo     74100.0
# 477        Tamale     15000.0
# 507       Cabinda     10000.0
# 508      Benguela     12000.0
# 509       Lubango     10000.0
# 516    Libreville     30000.0
# 517   Franceville      8000.0
# 521    Libreville     40000.0
# 523        Durban     45000.0
# 525     Nelspruit     27000.0
# 527     Nelspruit     35000.0
# 531          Bata     41000.0
# 537          Bata     32857.0
# 606         Cairo      7500.0
# 610    Alexandria      5890.0
# 613      Ismailia      8890.0
# 616          Suez      8233.0
# 618         Cairo      9143.0

# %%
print("===> With inplace=False")
display(type(df_african_cup_matches.dropna()))
print("===> With inplace=True")
display(type(df_african_cup_matches.dropna(inplace=True)))
# Out:
# ===> With inplace=False
# pandas.core.frame.DataFrame
# ===> With inplace=True
# NoneType

# %% [markdown]
# ## 5. df.interpolate()

# %%
df_african_cup_matches.interpolate()
# Out:
#      Year                      Date   Time      HomeTeam       AwayTeam  \
# 0    1957                  10-Feb-57    NaN       Sudan           Egypt
# 1    1957                  10-Feb-57    NaN    Ethiopia    South Africa
# 2    1957                  16-Feb-57    NaN       Egypt        Ethiopia
# 3    1959                  22-May-59    NaN        Egypt       Ethiopia
# 4    1959                  25-May-59    NaN       Sudan        Ethiopia
# ..    ...                        ...    ...          ...            ...
# 617  2019  11 July 2019 (2019-07-11)  21:00  Madagascar         Tunisia
# 618  2019  14 July 2019 (2019-07-14)  18:00     Senegal         Tunisia
# 619  2019  14 July 2019 (2019-07-14)  21:00     Algeria         Nigeria
# 620  2019  17 July 2019 (2019-07-17)  21:00     Tunisia         Nigeria
# 621  2019  19 July 2019 (2019-07-19)  21:00     Senegal         Algeria
#
#      HomeTeamGoals  AwayTeamGoals                 Stage  \
# 0              1.0            2.0            Semifinals
# 1              2.5            1.0            Semifinals
# 2              4.0            0.0                 Final
# 3              4.0            0.0      Final Tournament
# 4              1.0            0.0      Final Tournament
# ..             ...            ...                   ...
# 617            0.0            3.0        Quarter-finals
# 618            1.0            0.0           Semi-finals
# 619            2.0            1.0           Semi-finals
# 620            0.0            1.0  Third place play-off
# 621            0.0            1.0                 Final
#
#                                   SpecialWinConditions  \
# 0                                                  NaN
# 1    Ethiopia  wins due to disqualification of othe...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 617                                                NaN
# 618                              win after extra time
# 619                                                NaN
# 620                                                NaN
# 621                                                NaN
#
#                          Stadium       City  Attendance
# 0              Municipal Stadium   Khartoum     30000.0
# 1                            NaN        NaN     30000.0
# 2              Municipal Stadium   Khartoum     30000.0
# 3          Prince Farouk Stadium      Cairo     30000.0
# 4          Prince Farouk Stadium      Cairo     20000.0
# ..                           ...        ...         ...
# 617             Al Salam Stadium      Cairo      7568.0
# 618              30 June Stadium      Cairo      9143.0
# 619  Cairo International Stadium      Cairo     49775.0
# 620             Al Salam Stadium      Cairo      6340.0
# 621  Cairo International Stadium      Cairo     75000.0
#
# [622 rows x 12 columns]

# %% [markdown]
# # nlargest and nsmallest()

# %% [markdown]
# # Values_count
