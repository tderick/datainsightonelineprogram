# %%
import pandas as pd


df_teams_statistics = pd.read_csv('Participated Teams General Statistics.csv')

# %% [markdown]
# # 1. DataFrame.nlargest() and DataFrame.nsmallest()

# %%
df_teams_statistics.nlargest(5, columns='Rank')
# Out:
#     Rank       Team  Titles  Part's  Played  Win  Draw  Lose  Goal_For  \
# 41    42   Botswana     NaN       1       3    0     0     3         2
# 40    41  Mauritius     NaN       1       3    0     0     3         2
# 39    40    Burundi     NaN       1       3    0     0     3         0
# 38    39   Tanzania     NaN       2       6    0     1     5         5
# 37    38      Niger     NaN       2       6    0     1     5         1
#
#     Goal_Against  Goal_Difference  Points  Points%
# 41             9                7       0      0.0
# 40             8                6       0      0.0
# 39             4                4       0      0.0
# 38            14                9       1      5.5
# 37             9                8       1      5.6

# %%
df_teams_statistics.nsmallest(5, columns='Rank')
# Out:
#    Rank         Team  Titles  Part's  Played  Win  Draw  Lose  Goal_For  \
# 0     1        Egypt     7.0      24     100   57    17    26       164
# 1     2        Ghana     4.0      22      99   54    20    25       130
# 2     3      Nigeria     3.0      18      93   51    21    21       132
# 3     4  Ivory Coast     2.0      23      95   42    25    28       138
# 4     5     Cameroon     5.0      19      84   41    27    16       123
#
#    Goal_Against  Goal_Difference  Points  Points%
# 0            88               76     188     62.7
# 1            82               48     182     61.3
# 2            89               43     174     62.4
# 3           100               38     151     53.0
# 4            76               47     150     59.5

# %% [markdown]
# # DataFrame.query()

# %%
df_teams_statistics.head()
# Out:
#    Rank         Team  Titles  Part's  Played  Win  Draw  Lose  Goal_For  \
# 0     1        Egypt     7.0      24     100   57    17    26       164
# 1     2        Ghana     4.0      22      99   54    20    25       130
# 2     3      Nigeria     3.0      18      93   51    21    21       132
# 3     4  Ivory Coast     2.0      23      95   42    25    28       138
# 4     5     Cameroon     5.0      19      84   41    27    16       123
#
#    Goal_Against  Goal_Difference  Points  Points%
# 0            88               76     188     62.7
# 1            82               48     182     61.3
# 2            89               43     174     62.4
# 3           100               38     151     53.0
# 4            76               47     150     59.5

# %%
display(df_teams_statistics.query("Win > 20 & Lose < 20"))
display(df_teams_statistics.query("Win > 20 and Lose < 20"))
# Out:
#    Rank      Team  Titles  Part's  Played  Win  Draw  Lose  Goal_For  \
# 4     5  Cameroon     5.0      19      84   41    27    16       123
# 8     9   Morocco     1.0      17      65   24    23    18        74
#
#    Goal_Against  Goal_Difference  Points  Points%
# 4            76               47     150     59.5
# 8            58               16      95     48.7
#    Rank      Team  Titles  Part's  Played  Win  Draw  Lose  Goal_For  \
# 4     5  Cameroon     5.0      19      84   41    27    16       123
# 8     9   Morocco     1.0      17      65   24    23    18        74
#
#    Goal_Against  Goal_Difference  Points  Points%
# 4            76               47     150     59.5
# 8            58               16      95     48.7

# %%
display(df_teams_statistics.query('~(Titles >= 1)').head())
(df_teams_statistics.query('not(Titles >= 1)').head())
# Out:
#     Rank          Team  Titles  Part's  Played  Win  Draw  Lose  Goal_For  \
# 10    11       Senegal     NaN      15      60   23    14    23        69
# 11    12          Mali     NaN      11      50   17    17    16        61
# 13    14        Guinea     NaN      12      43   12    16    15        59
# 14    15  Burkina Faso     NaN      11      41    7    13    21        38
# 17    18         Gabon     NaN       7      21    6     7     8        19
#
#     Goal_Against  Goal_Difference  Points  Points%
# 10            54               15      83     46.1
# 11            64                3      68     45.3
# 13            63                4      52     40.3
# 14            62               24      34     27.6
# 17            26                7      25     39.7
#     Rank          Team  Titles  Part's  Played  Win  Draw  Lose  Goal_For  \
# 10    11       Senegal     NaN      15      60   23    14    23        69
# 11    12          Mali     NaN      11      50   17    17    16        61
# 13    14        Guinea     NaN      12      43   12    16    15        59
# 14    15  Burkina Faso     NaN      11      41    7    13    21        38
# 17    18         Gabon     NaN       7      21    6     7     8        19
#
#     Goal_Against  Goal_Difference  Points  Points%
# 10            54               15      83     46.1
# 11            64                3      68     45.3
# 13            63                4      52     40.3
# 14            62               24      34     27.6
# 17            26                7      25     39.7

# %%
df_teams_statistics.query("Win > 20 and Lose < 20")
# Out:
#    Rank      Team  Titles  Part's  Played  Win  Draw  Lose  Goal_For  \
# 4     5  Cameroon     5.0      19      84   41    27    16       123
# 8     9   Morocco     1.0      17      65   24    23    18        74
#
#    Goal_Against  Goal_Difference  Points  Points%
# 4            76               47     150     59.5
# 8            58               16      95     48.7

# %% [markdown]
# # DataFrame.where

# %%
df_teams_statistics.drop(columns='Team', inplace=True)
df_teams_statistics.head()
# Out:
#    Rank  Titles  Part's  Played  Win  Draw  Lose  Goal_For  Goal_Against  \
# 0     1     7.0      24     100   57    17    26       164            88
# 1     2     4.0      22      99   54    20    25       130            82
# 2     3     3.0      18      93   51    21    21       132            89
# 3     4     2.0      23      95   42    25    28       138           100
# 4     5     5.0      19      84   41    27    16       123            76
#
#    Goal_Difference  Points  Points%
# 0               76     188     62.7
# 1               48     182     61.3
# 2               43     174     62.4
# 3               38     151     53.0
# 4               47     150     59.5

# %%
df_teams_statistics.where(df_teams_statistics < 100, "HIGHT").head()
# Out:
#    Rank Titles  Part's Played  Win  Draw  Lose Goal_For Goal_Against  \
# 0     1    7.0      24  HIGHT   57    17    26    HIGHT           88
# 1     2    4.0      22     99   54    20    25    HIGHT           82
# 2     3    3.0      18     93   51    21    21    HIGHT           89
# 3     4    2.0      23     95   42    25    28    HIGHT        HIGHT
# 4     5    5.0      19     84   41    27    16    HIGHT           76
#
#    Goal_Difference Points Points%
# 0               76  HIGHT    62.7
# 1               48  HIGHT    61.3
# 2               43  HIGHT    62.4
# 3               38  HIGHT    53.0
# 4               47  HIGHT    59.5

# %%
df_teams_statistics.where(lambda x: x< 100, "OK").head()
# Out:
#    Rank Titles  Part's Played  Win  Draw  Lose Goal_For Goal_Against  \
# 0     1    7.0      24     OK   57    17    26       OK           88
# 1     2    4.0      22     99   54    20    25       OK           82
# 2     3    3.0      18     93   51    21    21       OK           89
# 3     4    2.0      23     95   42    25    28       OK           OK
# 4     5    5.0      19     84   41    27    16       OK           76
#
#    Goal_Difference Points Points%
# 0               76     OK    62.7
# 1               48     OK    61.3
# 2               43     OK    62.4
# 3               38     OK    53.0
# 4               47     OK    59.5
